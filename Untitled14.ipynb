# %%
import advanced_simulator_h5
import importlib

importlib.reload(advanced_simulator_h5)

data = advanced_simulator_h5.simulator(num_samples = 100, hgt_rate = 5, rho = 0)

mts = data['mts']

#mts.draw_svg()
gene_trees_list = data['gene_trees_list']

tree = gene_trees_list.first()

print("Expected Amount of sites: ", gene_trees_list.sequence_length*(1-(1-1/gene_trees_list.sequence_length)**gene_trees_list.num_mutations))
print("Expected Amount of mutations: ", gene_trees_list.sequence_length*0.1*tree.total_branch_length)

gene_trees_list
# Out:
# Clonal node: 545
# Present_mutation at node:  433
# Number of present genes:  56
# Success: hgt_rate = 5, Total computation time = 1.165586 seconds.
# Expected Amount of sites:  303.84373192795744
# Expected Amount of mutations:  356.50562927530086
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>1,000.0</td></tr>
#                             <tr><td>Time Units</td><td>unknown</td></tr>
#                             <tr><td>Sample Nodes</td><td>100</td></tr>
#                             <tr><td>Total Size</td><td>53.1 KiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">No Metadata</td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>144</td>
#                 <td>4.5 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>362</td>
#                 <td>13.7 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>911</td>
#                 <td>24.9 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>1</td>
#                 <td>16 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>1</td>
#                 <td>758 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>305</td>
#                 <td>8.0 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>06 September, 2025 at 04:12:59 AM</td>
#                     <td>msprime</td>
#                     <td>1.3.1</td>
#                     <td>sim_mutations</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: msprime<br/>version: 1.3.1<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: sim_mutations<br/>
#             <div>
#                 <span class="tskit-details-label">tree_sequence:</span>
#                 <details >
#                     <summary>dict</summary>
#                     __constant__: __current_ts__<br/>
#                 </details>
#             </div>
#             <br/>rate: 0.1<br/>
#             <div>
#                 <span class="tskit-details-label">model:</span>
#                 <details >
#                     <summary>dict</summary>
#                     __class__: msprime.mutations.InfiniteAlle&lt;br/&gt;les<br/>
#                 </details>
#             </div>
#             <br/>start_time: None<br/>end_time: None<br/>discrete_genome: None<br/>keep: True<br/>random_seed: 3017823703<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: AsusF<br/>release: 4.4.0-19041-Microsoft<br/>version: #5794-Microsoft Mon Apr 07&lt;br/&gt;17:55:00 PST 2025<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.1<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >

# %%
x = (1-(1-1/gene_trees_list.sequence_length)**gene_trees_list.num_mutations)

y = snp_percentage_of_gen_to_absolute_number(gene_trees_list.num_sites/gene_trees_list.sequence_length, gene_trees_list.sequence_length)
print(y)

z = absolute_number_to_snp_percentage_of_gen(y, gene_length, 0.1)

print(z)

np.log(1 - x) / np.log(1 - 1/gene_trees_list.sequence_length)
# Out:
# 363.66148136517995
# 0.30499999999999994
# 362.00000000000006

# %%
86.73 - (76.32+13.09-76.32*13.09/1000)
# Out:
# -1.6809711999999877

# %%
def snp_percentage_of_gen_to_absolute_number(x, gene_length):
    if x == 1:
        return np.inf
    else:
        y = np.log(1 - x) / np.log(1 - 1/gene_length)
    return y

def absolute_number_to_snp_percentage_of_gen(y, gene_length, nucleotide_mutation_rate):
    L = gene_length
    mu = nucleotide_mutation_rate
    if y == np.inf:
        return 1
    else:
        return 1 - np.exp(y * np.log(1 - 1/L))

# %%
import msprime
import tskit
import hgt_simulation
import hgt_sim_args
import numpy as np
import networkx as nx
import random
import torch
import os
import re
import secrets
import copy
import json
import h5py
import uuid
import glob
import shutil
import pickle
import time

from random import randint
from collections import namedtuple
from collections import defaultdict
from collections import deque
from sbi.utils import BoxUniform
from sklearn.decomposition import PCA
from scipy.spatial.distance import pdist, squareform
from numba import njit
from typing import Union, Sequence, List, Tuple
from networkx.readwrite import json_graph

from concurrent.futures import ProcessPoolExecutor

def distance_core(tree_sequence: tskit.TreeSequence, num_samples: int) -> np.ndarray:
    
    tree = tree_sequence.first()
    distance_matrix = np.zeros((num_samples, num_samples))

    for i in range(num_samples):
        time_i = tree.get_time(i)
        for j in range(i):
            time_j = tree.get_time(j)
            mrca = tree.mrca(i, j)
            time_mrca = tree.get_time(mrca)

            # Distance is the time between each sample and their MRCA
            distance = (time_mrca - time_i) + (time_mrca - time_j)
            distance_matrix[i, j] = distance
            distance_matrix[j, i] = distance  # symmetric

    return distance_matrix

def multidimensional_scaling(D, multidimensional_scaling_dimensions=100):

    # 1. Quadrat der Abstände
    D2 = D ** 2

    # 2. Zentrierungsmatrix
    n = D.shape[0]
    J = np.eye(n) - np.ones((n, n)) / n

    # 3. Doubly centered inner product matrix
    B = -0.5 * J @ D2 @ J

    # 4. Eigenzerlegung
    eigvals, eigvecs = np.linalg.eigh(B)

    # 5. Sortieren (absteigend)
    idx = np.argsort(eigvals)[::-1]
    eigvals = eigvals[idx]
    eigvecs = eigvecs[:, idx]

    # 6. Komponenten auswählen
    L = np.diag(np.sqrt(np.maximum(eigvals[:multidimensional_scaling_dimensions], 0)))
    V = eigvecs[:, :multidimensional_scaling_dimensions]

    out = V @ L  # → [n, multidimensional_scaling_dimensions]

    if out.shape[1] < multidimensional_scaling_dimensions:
        padding = np.zeros((out.shape[0], multidimensional_scaling_dimensions - out.shape[1]))
        out = np.hstack([out, padding])
    
    return out

def count_blocks_sym(mat: np.ndarray,
                     threshold: Union[float, Sequence[float]] = 0.05
                    ) -> List[Tuple[np.ndarray, int]]:

    assert mat.ndim == 2 and mat.shape[0] == mat.shape[1], "Matrix muss quadratisch sein."
    thresholds = np.atleast_1d(threshold).astype(np.float64)

    if mat.size == 0:
        return np.zeros_like(thresholds)
    
    # Vorarbeit außerhalb der Schleife
    idx = np.where(~np.isnan(mat[0]))[0]

    #results_matrices = []
    results_number_of_clusters = []
    for th in thresholds:
        labels, k = _count_blocks_single(mat, idx, th)
        #results_matrices.append(labels)
        results_number_of_clusters.append(int(k))
    results_number_of_clusters = np.array(results_number_of_clusters, dtype=int)
    #return results_matrices, results_number_of_clusters
    return results_number_of_clusters

def _count_blocks_single(mat, idx, threshold):
    n = idx.size
    label_matrix = -np.ones((n, n), dtype=np.int32)
    num_labels   = 0

    for ii in range(n):
        i = idx[ii]
        for jj in range(ii, n):
            j = idx[jj]
            if ii == 0 and jj == 0:
                label_matrix[ii, jj] = 0
                num_labels += 1
            elif ii == 0:
                if abs(mat[i, j] - mat[i, idx[jj-1]]) < threshold:
                    label_matrix[ii, jj] = label_matrix[ii, jj-1]
                else:
                    label_matrix[ii, jj] = num_labels
                    num_labels += 1
            else:
                if abs(mat[i, j] - mat[idx[ii-1], j]) < threshold:
                    label_matrix[ii, jj] = label_matrix[ii-1, jj]
                elif abs(mat[i, j] - mat[i, idx[jj-1]]) < threshold:
                    label_matrix[ii, jj] = label_matrix[ii, jj-1]
                else:
                    label_matrix[ii, jj] = num_labels
                    num_labels += 1
    return label_matrix, num_labels

# %%
num_samples = 100
theta = 1
rho = 1
hgt_rate = 1
num_genes = 1
nucleotide_mutation_rate = None
gene_length = 1000
pca_dimensions = 10
ce_from_nwk = None
seed = None
distance_matrix = None
multidimensional_scaling_dimensions = 100
block_clustering_threshold = np.arange(0, 1.0001, 0.025)
clonal_root_mutation = None
hgt_difference_removal_threshold = 0

start_time = time.time()

if ce_from_nwk is None and num_samples is None:
    raise ValueError(
        "Neither a core tree or parameters for simulation were provided. Choose either."
    )

if ce_from_nwk is None:
    core_tree = msprime.sim_ancestry(
            samples=num_samples,
            sequence_length=1,
            ploidy=1,
            recombination_rate=0,
            gene_conversion_rate=0,
            gene_conversion_tract_length=1,  # One gene
            random_seed=seed,
        )

    ce_from_nwk = core_tree.first().newick()

random.seed(seed)
np.random.seed(seed)

if seed is None:
    seed = secrets.randbelow(2**32 - 4) + 2

if nucleotide_mutation_rate is None:
    #nucleotide_mutation_rate = np.random.uniform(0.033, 0.066)
    nucleotide_mutation_rate = np.random.uniform(0.05)

if num_samples < multidimensional_scaling_dimensions:
    multidimensional_scaling_dimensions = num_samples


### Calculate hgt events:

args = hgt_sim_args.Args(
    sample_size=num_samples,
    num_sites=num_genes,
    gene_conversion_rate=0,
    recombination_rate=0,
    hgt_rate=hgt_rate,
    ce_from_ts=None,
    ce_from_nwk=ce_from_nwk,
    random_seed=seed,
    #random_seed=84,
)

ts, hgt_edges = hgt_simulation.run_simulate(args)
        
### Place mutations

alleles = ["absent", "present"]

# Place one mutation per site, e.g. gen

gains_model = msprime.MatrixMutationModel(
    alleles = alleles,
    root_distribution=[1, 0],
    transition_matrix=[
        [0, 1],
        [0, 1],
    ],
)

ts_gains = msprime.sim_mutations(ts, rate=1, model = gains_model, keep = True, random_seed=seed)

k = 1
while (ts_gains.num_sites < ts_gains.sequence_length):
    ts_gains = msprime.sim_mutations(ts_gains, rate=1, model = gains_model, keep = True, random_seed=seed+k)
    k = k+1

# Remove superfluous mutations

tables = ts_gains.dump_tables()

mutations_by_site = {}
for mut in tables.mutations:
    if mut.site not in mutations_by_site:
        mutations_by_site[mut.site] = []
    mutations_by_site[mut.site].append(mut)

tables.mutations.clear()

clonal_root_node = ts_gains.first().mrca(*list(range(num_samples)))

print("Clonal node:", clonal_root_node)

if clonal_root_mutation == None:
    clonal_root_mutation = random.random() < 0.5

present_mutations = [[] for i in range(num_genes)]
for site, mutations in mutations_by_site.items():

    if clonal_root_mutation == True:
        tables.mutations.add_row(
            site=site,
            node=clonal_root_node,
            derived_state="present",
            parent=-1,
            metadata=None,
            time=tables.nodes.time[clonal_root_node],
        )
        
    else:
        selected_mutation = random.choice(mutations)
        tables.mutations.add_row(
            site=selected_mutation.site,
            node=selected_mutation.node,
            derived_state=selected_mutation.derived_state,
            parent=-1,
            metadata=None,
            time=selected_mutation.time,
        )
        present_mutations[site].append(selected_mutation)

        # Mutation at clonal root:
        tables.mutations.add_row(
            site=site,
            node=clonal_root_node,
            derived_state="absent",
            parent=-1,
            metadata=None,
            time=tables.nodes.time[clonal_root_node],
        )

    # Add sentinel mutations at the leafs:

    for leaf_position in range(num_samples):
        tables.mutations.add_row(
            site = site,
            node = leaf_position,
            derived_state = "absent",
            time = 0.00000000001,
        )

tables.sort()
ts_gains = tables.tree_sequence()


# Place losses:

losses_model = msprime.MatrixMutationModel(
    alleles = alleles,
    root_distribution=[1, 0],
    transition_matrix=[
        [1, 0],
        [1, 0],
    ],
)

ts_gains_losses = msprime.sim_mutations(ts_gains, rate = rho, model = losses_model, keep = True, random_seed=seed-1)

### Calculate the gene absence presence matrix:

MutationRecord = namedtuple('MutationRecord', ['site_id', 'mutation_id', 'node', 'is_hgt'])

tables = ts_gains_losses.dump_tables()

tables.mutations.clear() # SIMPLE VERSION!

hgt_parent_nodes = [edge.parent-1 for edge in hgt_edges]
hgt_children_nodes = [edge.child for edge in hgt_edges]
hgt_parent_children = defaultdict(list)

for parent in hgt_parent_nodes:
    hgt_parent_children[parent].append(parent-1)



# Initialize tables for the diversity of each gene
tables_gene = tskit.TableCollection(sequence_length=gene_length)
tables_gene.nodes.replace_with(ts_gains_losses.tables.nodes)
tables_gene.populations.replace_with(ts_gains_losses.tables.populations)


tables_gene_list = [copy.deepcopy(tables_gene) for _ in range(num_genes)]
gene_number_hgt_events_passed = [0 for _ in range(num_genes)]
gene_number_loss_events = [0 for _ in range(num_genes)]
gene_nodes_loss_events = [[] for _ in range(num_genes)]
gene_trees_list = []


for tree in ts_gains_losses.trees():

    for site in tree.sites():
        
        hgt_parent_children_passed = [False] * ts_gains_losses.num_nodes
        mutations = site.mutations
        #site = list(tree.sites())[0]
        
        present_mutation = [m for m in mutations if m.derived_state == "present"][0]
        absent_mutation_nodes = {m.node for m in mutations if m.derived_state == "absent"}

        absent_mutations = defaultdict(list)
        for m in mutations:
            if m.derived_state == "absent" and m.time < present_mutation.time:
                absent_mutations[m.node].append(m)

        branching_nodes_reached_before = defaultdict(list)
        for node_id in range(ts_gains_losses.num_nodes):
            branching_nodes_reached_before[node_id] = False
    
        print("Present_mutation at node: ", present_mutation.node)
    
        branching_nodes_to_process = deque([(present_mutation.node, False, False, 0)])
        # The second variable describes if a hgt edge was passed the whole way down to the actual node. 
        # The third describes if a hgt edge was passed in the last step.
        # The fourth is the number of hgt edges that were passed.
    
        child_mutations = []
    
        if present_mutation.node < num_samples: # Gain directly above leaf:
            if present_mutation.id == sorted([mut for mut in mutations if mut.node == present_mutation.node], key=lambda m: m.time)[1].id:
                sentinel_mutation = min([mut for mut in absent_mutations[present_mutation.node]], key=lambda m: m.time)
                child_mutations.append(MutationRecord(
                    site_id=site.id,
                    mutation_id=sentinel_mutation.id,
                    node=sentinel_mutation.node,
                    is_hgt=False
                ))
                if not tree.parent(present_mutation.node) == -1: # Can occur if its a clonal root mutation
                    tables_gene_list[site.id].edges.add_row(
                            left = 0, right = gene_length, parent = tree.parent(present_mutation.node), child = sentinel_mutation.node
                    )
            else:
                gene_number_loss_events[site.id] += 1
                gene_nodes_loss_events[site.id].append(present_mutation.node)
    
        else: 
            
            # To see, which HGT edges are passed, we have to go through the tree two times. 
            # First, we detect all passed HGT edges, then we calculate the presence of mutations in the leaves.
    
            # First time going through:
            while branching_nodes_to_process:
                
                last_branching_node = branching_nodes_to_process.popleft()
                selected_branch_nodes_to_process = deque([last_branching_node])
                branching_nodes_reached_before[tree.parent(last_branching_node[0])] = True
                
                while selected_branch_nodes_to_process:
                
                    child_node = selected_branch_nodes_to_process.popleft()    
        
                    # If there is a mutation on the edge, find the earliest one.
                    if not child_node[2] and child_node[0] in absent_mutation_nodes:
                        
                        absent_mutation_after_gain_at_node = absent_mutations[child_node[0]]
                        
                        if not absent_mutation_after_gain_at_node: # empty
                            children = tree.children(child_node[0])
                            if len(children) > 1:
                                for child in reversed(children):
                                    if not branching_nodes_reached_before[child_node[0]]:
                                        branching_nodes_to_process.extendleft([(child, child_node[1], False, 0)])
                                    #else:
                                    #    print("Child passed before", " Child: ", child)
                            else:
                                for child in reversed(children):
                                    selected_branch_nodes_to_process.extendleft([(child, child_node[1], False, child_node[3])])
                            if hgt_parent_children[child_node[0]]:
                                selected_branch_nodes_to_process.extendleft([(hgt_parent_children[child_node[0]][0], True, True, child_node[3] + 1)])
                                hgt_parent_children_passed[hgt_parent_children[child_node[0]][0]] = True # The child of the hgt_edge is marked
                                #print("HGT at Node: ", hgt_parent_children[child_node[0]][0])
                            
            
                    # If there is no mutation, add child nodes.
                    else:
                        children = tree.children(child_node[0])
                        if len(children) > 1:
                            for child in reversed(children):
                                #print("Child: ", child)
                                if not branching_nodes_reached_before[child_node[0]]:
                                    branching_nodes_to_process.extendleft([(child, child_node[1], False, 0)])
                                #else:
                                #    print("Child passed before", " Child: ", child)
                        else:
                            for child in reversed(children):
                                #print("Child: ", child)
                                selected_branch_nodes_to_process.extendleft([(child, child_node[1], False, child_node[3])])
                        if hgt_parent_children[child_node[0]]:
                            selected_branch_nodes_to_process.extendleft([(hgt_parent_children[child_node[0]][0], True, True, child_node[3] + 1)])
                            hgt_parent_children_passed[hgt_parent_children[child_node[0]][0]] = True # The child of the hgt_edge is marked
                            #print("HGT at Node: ", hgt_parent_children[child_node[0]][0])
    
            # Second time going through:
            
            branching_nodes_to_process = deque([(present_mutation.node, False, False, 0)])

            branching_nodes_reached_before = defaultdict(list)
            for node_id in range(ts_gains_losses.num_nodes):
                branching_nodes_reached_before[node_id] = False
            
            while branching_nodes_to_process:
                
                last_branching_node = branching_nodes_to_process.popleft()
                selected_branch_nodes_to_process = deque([last_branching_node])
                branching_nodes_reached_before[tree.parent(last_branching_node[0])] = True
                
                while selected_branch_nodes_to_process:
                
                    child_node = selected_branch_nodes_to_process.popleft()
    
                    if not child_node[2] and hgt_parent_children_passed[child_node[0]]:
                        #print("Incoming HGT edge registered at node: ", child_node[0])
                        continue
        
                    # If there is a mutation on the edge, find the earliest one.
                    if not child_node[2] and child_node[0] in absent_mutation_nodes:
                        
                        absent_mutation_after_gain_at_node = absent_mutations[child_node[0]]
                        
                        if absent_mutation_after_gain_at_node: # not empty
                            earliest_mutation = max(
                                absent_mutations[child_node[0]], 
                                key=lambda m: m.time
                            )
            
                            if earliest_mutation.time == 0.00000000001:
                                earliest_mutation.derived_state = "present"
                                child_mutations.append(MutationRecord(
                                    site_id=site.id,
                                    mutation_id=earliest_mutation.id,
                                    node=earliest_mutation.node,
                                    is_hgt=child_node[1]
                                ))
                                tables_gene_list[site.id].edges.add_row(
                                    left = 0, right = gene_length, parent = tree.parent(last_branching_node[0]), child = earliest_mutation.node
                                )
                                gene_number_hgt_events_passed[site.id] += child_node[3]
                            else:
                                gene_number_loss_events[site.id] += 1
                                gene_nodes_loss_events[site.id].append(earliest_mutation.node)
                        else:
                            children = tree.children(child_node[0])
                            if len(children) > 1:
                                for child in reversed(children):
                                    if not branching_nodes_reached_before[child_node[0]]:
                                        branching_nodes_to_process.extendleft([(child, child_node[1], False, 0)])
                                if not tree.parent(last_branching_node[0]) == -1:
                                    tables_gene_list[site.id].edges.add_row(
                                            left = 0, right = gene_length, parent = tree.parent(last_branching_node[0]), child = child_node[0]
                                    )
                                gene_number_hgt_events_passed[site.id] += child_node[3]
                            else:
                                for child in reversed(children):
                                    selected_branch_nodes_to_process.extendleft([(child, child_node[1], False, child_node[3])])
                            if hgt_parent_children[child_node[0]]:
                                selected_branch_nodes_to_process.extendleft([(hgt_parent_children[child_node[0]][0], True, True, child_node[3] + 1)])  
                            
            
                    # If there is no mutation, add child nodes.
                    else:
                        children = tree.children(child_node[0])
                        if len(children) > 1:
                            for child in reversed(children):
                                if not branching_nodes_reached_before[child_node[0]]:
                                    branching_nodes_to_process.extendleft([(child, child_node[1], False, 0)])
                            if not tree.parent(last_branching_node[0]) == -1:
                                tables_gene_list[site.id].edges.add_row(
                                        left = 0, right = gene_length, parent = tree.parent(last_branching_node[0]), child = child_node[0]
                                )
                            gene_number_hgt_events_passed[site.id] += child_node[3]
                        else:
                            for child in reversed(children):
                                selected_branch_nodes_to_process.extendleft([(child, child_node[1], False, child_node[3])])
                        if hgt_parent_children[child_node[0]]:
                            selected_branch_nodes_to_process.extendleft([(hgt_parent_children[child_node[0]][0], True, True, child_node[3] + 1)])

        child_mutations.sort(key=lambda mut: not mut.is_hgt) # Will set is_hgt to False later if there are paths without hgt events to the leaf.
    
        # We have to adress multiple paths to the same destiny, some with hgt and other without it:
        unique_mutations = {}
    
        for mut in child_mutations:
            if mut.node not in unique_mutations:
                unique_mutations[mut.node] = mut
            else:
                existing_mut = unique_mutations[mut.node]
                if not existing_mut.is_hgt or not mut.is_hgt:
                    unique_mutations[mut.node] = mut._replace(is_hgt=False)
        
        child_mutations_filtered = list(unique_mutations.values())

        for mutation in mutations:
            if mutation.time > 0.00000000001:
                if mutation.derived_state == "absent":
                    metadata_value = bytes([3]) 
                elif mutation.derived_state == "present":
                    metadata_value = bytes([7])
                tables.mutations.add_row(
                    site=site.id,
                    node=mutation.node,
                    derived_state=mutation.derived_state,
                    parent=-1,
                    metadata=metadata_value,
                    time=mutation.time,
                )
        
        for mutation in child_mutations_filtered:
    
            tables.mutations.add_row(
                site=site.id,
                node=mutation.node,
                derived_state="present",
                parent=-1,
                metadata=bytes([mutation.is_hgt]),
                time=0.00000000001,
            )
    

mts = tables.tree_sequence()

for i in range(num_genes): 

    tables_gene_list[i].sort()
    
    gene_trees_list.append(tables_gene_list[i].tree_sequence())

### Compute the gene presence and absence:

gene_absence_presence_matrix = []

for var in mts.variants():
    gene_absence_presence_matrix.append(var.genotypes)
gene_absence_presence_matrix = np.array(gene_absence_presence_matrix)

print("Number of present genes: ", sum(gene_absence_presence_matrix[0]))

#fitch_scores = fitch_parsimony_score(mts, gene_absence_presence_matrix)

### Calculate the HGT events:

gene_number_hgt_events_passed = [0 for _ in range(num_genes)]
nodes_hgt_events = [[] for _ in range(num_genes)]
hgt_trees = [[] for _ in range(num_genes)]

for tree in mts.trees():
    for site in tree.sites():
        reached_nodes_from_leaves = defaultdict(list)
        for node_id in range(mts.num_nodes):
            reached_nodes_from_leaves[node_id] = False
        
        stack = []
        for node_id in range(mts.num_samples):
            if gene_absence_presence_matrix[site.id][node_id]:
                stack.append((node_id, node_id))
                
        while stack:
            node, leaf_node = stack.pop()
            parent = tree.parent(node)
            if not hgt_parent_children_passed[node] and not reached_nodes_from_leaves[node] and node < clonal_root_node:
                stack.append((parent, leaf_node))
                reached_nodes_from_leaves[node] = True
            elif hgt_parent_children_passed[node] and not reached_nodes_from_leaves[node] and node < clonal_root_node:
                #print("HGT event spotted at node: ", node)
                nodes_hgt_events[site.id].append((node, leaf_node))
                gene_number_hgt_events_passed[site.id] += 1
                reached_nodes_from_leaves[node] = True

        tables = gene_trees_list[site.id].tables
        for subtree in gene_trees_list[site.id].trees():
            for node, leaf_node in nodes_hgt_events[site.id]:
                temp_time = 0
                parent = leaf_node
                time_of_node = gene_trees_list[site.id].node(node).time
                while temp_time < time_of_node:
                    child = parent
                    parent = subtree.parent(parent)
                    temp_time = gene_trees_list[site.id].node(parent).time

                mask = [
                    not (edge.parent == parent and edge.child == child)
                    for edge in tables.edges
                ]
                
                tables.edges.set_columns(
                    left=[e.left for i, e in enumerate(tables.edges) if mask[i]],
                    right=[e.right for i, e in enumerate(tables.edges) if mask[i]],
                    parent=[e.parent for i, e in enumerate(tables.edges) if mask[i]],
                    child=[e.child for i, e in enumerate(tables.edges) if mask[i]],
                )
                
                tables.edges.add_row(left = 0, right = gene_length, parent=node, child=child)
                tables.edges.add_row(left = 0, right = gene_length, parent=parent, child=node)

        tables.sort()
        gene_trees_list[site.id] = tables.tree_sequence()

        valid_nodes_hgt_events = []
        for subtree in gene_trees_list[site.id].trees():
            for node, leaf_node in nodes_hgt_events[site.id]:

                tables = mts.tables
                
                temp_time = 0
                parent = leaf_node
                time_of_node = gene_trees_list[site.id].node(node).time

                mask = [
                    not (edge.parent == tree.parent(node) and edge.child == node)
                    for edge in tables.edges
                ]

                tables.edges.set_columns(
                    left=[e.left for i, e in enumerate(tables.edges) if mask[i]],
                    right=[e.right for i, e in enumerate(tables.edges) if mask[i]],
                    parent=[e.parent for i, e in enumerate(tables.edges) if mask[i]],
                    child=[e.child for i, e in enumerate(tables.edges) if mask[i]],
                )
                
                tables.edges.add_row(left = site.id, right = site.id+1, parent=subtree.parent(node), child=node)

                tables.sort()
                tables.mutations.clear()

                hgt_tree = tables.tree_sequence()

                hgt_trees[site.id].append((hgt_tree, (node, leaf_node)))
                
                keep = False
                for leaf in range(num_samples):
                    if gene_absence_presence_matrix[site.id][leaf] == 1 and abs(
                        hgt_tree.node(hgt_tree.at(hgt_tree.sites()[site.id].position).mrca(node, leaf)).time - mts.node(tree.mrca(node, leaf)).time) > hgt_difference_removal_threshold:
                        keep = True
                        break
                if keep:
                    valid_nodes_hgt_events.append((node, leaf_node))
                else:
                    print("Removed HGT edge")
        nodes_hgt_events[site.id] = valid_nodes_hgt_events
            

# Simulate the tree for each gene:

"""
nucleotide_mutation = msprime.MatrixMutationModel(
        alleles=["C", "M1", "M2", "M3"],
        root_distribution=[1.0, 0.0, 0.0, 0.0],  # nur C als Wurzel
        transition_matrix=[
            # C     M1     M2     M3
            [ 0.0,  1/3,  1/3,  1/3 ], 
            [ 1/3,  0,    1/3,  1/3 ],  
            [ 1/3,  1/3,  0.0,  1/3 ],  
            [ 1/3,  1/3,  1/3,  0.0 ],  
        ]
    )
"""
nucleotide_mutation = msprime.MatrixMutationModel(
    alleles=["C", "M"],
    root_distribution=[1.0, 0.0],  # nur C als Wurzel
    transition_matrix=[
        # C     M     
        [ 0.0,  1 ], 
        [ 1/3,  2/3],  
    ]
)


nucleotide_mutation = msprime.InfiniteAlleles()


for i in range(num_genes): 
    
    gene_trees_list[i] = msprime.sim_mutations(gene_trees_list[i], 
                                               rate = nucleotide_mutation_rate, model = nucleotide_mutation, keep = True, random_seed=seed-1)

# Calculate the different alleles:

alleles_list = []

for i in range(num_genes):
    alleles_list.append([])
    for var in gene_trees_list[i].variants():
        alleles_list[i].append(var.genotypes)
    alleles_list[i] = np.array(alleles_list[i])

### Calculate the distances between the leaves

if distance_matrix is None:
    distance_matrix = distance_core(tree_sequence = mts, num_samples = num_samples)
scaled_distance_matrix = multidimensional_scaling(distance_matrix, multidimensional_scaling_dimensions = multidimensional_scaling_dimensions)

# Distances in alleles (no pca)

alleles_list_pca = []
core_allel_distance_list = []
core_allel_distance_number_of_clusters = []

for A in alleles_list:

    if A.shape[0] == 0:
        A_reconstructed = np.full((num_samples, multidimensional_scaling_dimensions), -1)
        alleles_list_pca.append(A_reconstructed)
        continue

    gene_absent_vector = (A[0] == -1)
    gene_present_vector = ~gene_absent_vector

    # Berechne die paarweisen Hamming-Distanzen
    euclidean_distances = squareform(pdist(A.T, metric='euclidean')) # Will be transformed into Hamming distances later.
    
    scaled_euclidean_distances = np.full((num_samples, multidimensional_scaling_dimensions), 0.0)
    
    if gene_present_vector.sum() > 0:
        scaled_euclidean_distances[gene_present_vector, :] = multidimensional_scaling(
            euclidean_distances[np.ix_(gene_present_vector, gene_present_vector)], multidimensional_scaling_dimensions = multidimensional_scaling_dimensions)

    euclidean_distances[gene_absent_vector, : ] = -1
    euclidean_distances[:, gene_absent_vector ] = -1

    alleles_list_pca.append(scaled_euclidean_distances)

    distance_matrix_valid = distance_matrix[np.ix_(gene_present_vector, gene_present_vector)]
    euclidean_distances_valid = euclidean_distances[np.ix_(gene_present_vector, gene_present_vector)]
    euclidean_distances_valid = euclidean_distances_valid ** 2 # Return to Hamming distances.
    
    if gene_present_vector.sum() > 0 and np.max(euclidean_distances_valid) > 0:
        euclidean_distances_valid = euclidean_distances_valid / np.mean(euclidean_distances_valid) * np.mean(distance_matrix_valid)

    core_allel_distance_valid = distance_matrix_valid - euclidean_distances_valid

    core_allel_distance_list.append(core_allel_distance_valid)

    core_allel_distance_cluster_results = count_blocks_sym(core_allel_distance_valid, block_clustering_threshold)
    
    core_allel_distance_number_of_clusters.append(core_allel_distance_cluster_results)

### Construct the graph:

tree = mts.first()
children = defaultdict(list)
for leaf in range(num_samples):
    node = leaf
    while node < clonal_root_node and len(children[node]) < 2:
        parent = tree.parent(node)
        children[parent].append(node)
        node = parent
        if parent == tskit.NULL:
            break
              
for node in list(children):
    if len(children[node]) == 1:
        parent = tree.parent(node)
        if parent == tskit.NULL:
            continue  # kein Parent → überspringen
        child = children[node][0]  # das eine Kind

        # 1. altes Kind durch neues Kind ersetzen
        if node in children[parent]:
            children[parent].remove(node)
        children[parent].append(child)

        # 2. entferne den Zwischenknoten
        del children[node]

parents = defaultdict(int)
for parent, child_list in children.items():
    for child in child_list:
        parents[child] = parent

node_to_leaf = defaultdict(list)
for child in sorted(list(parents)):
    if child < num_samples:
        node_to_leaf[child] = [child]
    node_to_leaf[parents[child]].extend(node_to_leaf[child])

Graphs = []
graph_properties = []
parental_nodes_hgt_events = [[] for _ in range(num_genes)]
parental_nodes_hgt_events_corrected = [[] for _ in range(num_genes)]
children_gene_nodes_loss_events = [[] for _ in range(num_genes)]

for tree in mts.trees():
    for site in tree.sites():
        
        G = nx.DiGraph()
        # Alle Knoten sammeln
        all_nodes = set(children.keys())
        for child_list in children.values():
            all_nodes.update(child_list)
        
        # Sortierte Nodes hinzufügen
        for node in sorted(all_nodes):
            G.add_node(node, core_distance=0, allele_distance=0, time = tree.get_time(node))
            
        for parent, child_list in children.items():
            for child in child_list:
                G.add_edge(child, parent)

        #### Add allele distances:
        
        # Calculate for every node the number of SNPs below it.
        allele_distances = defaultdict(list)
        gene_present_bool = gene_absence_presence_matrix[site.id] == 1
        
        for node, leaves in node_to_leaf.items():
            if alleles_list[site.id].ndim == 1:
               alleles_list[site.id] = np.zeros((1, num_samples), dtype=int)
            leaves_arr = np.array(leaves)
            valid_cols = leaves_arr[gene_present_bool[leaves_arr]]
            if valid_cols.size == 0:
                distance = 0
            else:
                subset = alleles_list[site.id][:, valid_cols]
                distance = np.count_nonzero(np.ptp(subset, axis=1)) # ptp = max - min
            allele_distances[tuple(leaves)] = distance

        # Calculate for every node the number of SNPs below it which were not already SNPs in at least one of the children (new SNPs).
        allele_distances_only_new = defaultdict(list)
        gene_present_bool = gene_absence_presence_matrix[site.id] == 1
        
        for node, leaves in node_to_leaf.items():
            if alleles_list[site.id].ndim == 1:
                alleles_list[site.id] = np.zeros((1, num_samples), dtype=int)
        
            leaves_arr = np.array(leaves)
            valid_cols = leaves_arr[gene_present_bool[leaves_arr]]
        
            if valid_cols.size == 0:
                distance = 0
            else:
                subset = alleles_list[site.id][:, valid_cols]
                
                # Polymorphe Positionen im aktuellen Knoten
                polymorph_mask = np.ptp(subset, axis=1) > 0   # shape = [num_sites]
                
                # Kinder-Masken sammeln
                child_polymorph_mask_list = []
                for child in G.predecessors(node): 
                    child_leaves = np.array(node_to_leaf[child])
                    child_valid = child_leaves[gene_present_bool[child_leaves]]
                    child_subset = alleles_list[site.id][:, child_valid]
                
                    if child_valid.size > 0:
                        child_mask = np.ptp(child_subset, axis=1) > 0
                    else:
                        child_mask = np.zeros(subset.shape[0], dtype=bool)
                
                    child_polymorph_mask_list.append(child_mask)
                
                if child_polymorph_mask_list:
                    # OR über alle Kinder -> Position polymorph in mind. einem Kind
                    child_any_mask = np.logical_or.reduce(child_polymorph_mask_list)
                else:
                    # keine Kinder -> leerer OR = False
                    child_any_mask = np.zeros_like(polymorph_mask)
                
                # Nur Positionen, die polymorph sind UND in allen Kindern noch monomorph
                new_polymorph_mask = polymorph_mask & (~child_any_mask)
                
                distance = np.count_nonzero(new_polymorph_mask)
                
            allele_distances_only_new[tuple(leaves)] = distance
            

        for node in list(parents) + [clonal_root_node]:
            G.nodes[node]["allele_distance"] = allele_distances[tuple(node_to_leaf[node])] / gene_length
            G.nodes[node]["allele_distance_only_new"] = allele_distances_only_new[tuple(node_to_leaf[node])] / gene_length

        for gen_tree in gene_trees_list[site.id].trees():
            for node in list(parents) + [clonal_root_node]:
                
                # Calculate the expected number of alleles, which also can be seen as the true allele distance:
                leaves = [leaf for leaf in node_to_leaf[node] if gene_absence_presence_matrix[site.id][leaf] == 1]
                if len(leaves) <= 1:
                    G.nodes[node]["true_allele_distance"] = 0
                else:
                    m = leaves[0]
                    for u in leaves[1:]:
                        m = gen_tree.mrca(m, u) # The most recent common ancestor of all leaves from the node
                    
                    visited_edges = set()
                    total_length = 0.0 
                    for leaf in leaves:
                        u = leaf
                        while u != tskit.NULL and u < m:
                            p = gen_tree.parent(u)
                            if p == tskit.NULL:
                                break
                            edge = (p, u)
                            if edge not in visited_edges:
                                visited_edges.add(edge)
                                total_length += gen_tree.time(p) - gen_tree.time(u)
                            # weiter hoch
                            u = p
          
                    # The expected proportion of SNPS:
                    G.nodes[node]["true_allele_distance"] = (1 - (1 - 1/gene_length)**round(total_length * nucleotide_mutation_rate * gene_length))

        ### Add clonal distances:
        subtree_has_gene = {}
        for node in range(clonal_root_node):
            if node < num_samples:
                if gene_absence_presence_matrix[site.id][node] == 1:
                    subtree_has_gene[node] = True
                else:
                    subtree_has_gene[node] = False
            else:
                child_list = children[node]
                if any(subtree_has_gene[child] for child in child_list):
                    subtree_has_gene[node] = True
                else:
                    subtree_has_gene[node] = False

        for node in range(num_samples, clonal_root_node + 1):
            if node in G.nodes:
                c0, c1 = children[node]  # Entpacke einmal
                c0_has, c1_has = subtree_has_gene[c0], subtree_has_gene[c1]
            
                # Falls beide Subtrees kein Gen enthalten, können wir überspringen
                if not (c0_has or c1_has):
                    continue
            
                if c0_has and c1_has:
                    node_time = tree.get_time(node)
                    core_distance = (
                        2 * node_time
                        - tree.get_time(c0) - tree.get_time(c1)
                        + G.nodes[c0]["core_distance"]
                        + G.nodes[c1]["core_distance"]
                    )
                if c0_has and c1_has:
                    # Finde tiefste Kinderknoten, bei denen beide Subtrees True sind
                    if c0 >= num_samples:
                        d0, d1 = children[c0]
                        while (not subtree_has_gene[d0] and subtree_has_gene[d1]) or (subtree_has_gene[d0] and not subtree_has_gene[d1]):
                            if subtree_has_gene[d0]:
                                c0 = d0
                                if d0 < num_samples:
                                    break
                            elif subtree_has_gene[d1]:
                                c0 = d1
                                if d1 < num_samples:
                                    break
                            d0, d1 = children[c0]
                                    
                    if c1 >= num_samples:
                        d0, d1 = children[c1]
                        while (not subtree_has_gene[d0] and subtree_has_gene[d1]) or (subtree_has_gene[d0] and not subtree_has_gene[d1]):
                            if subtree_has_gene[d0]:
                                c1 = d0
                                if d0 < num_samples:
                                    break
                            elif subtree_has_gene[d1]:
                                c1 = d1
                                if d1 < num_samples:
                                    break
                            d0, d1 = children[c1]
         
                    node_time = tree.get_time(node)
                    core_distance = (
                        2 * node_time
                        - tree.get_time(c0) - tree.get_time(c1)
                        + G.nodes[c0]["core_distance"]
                        + G.nodes[c1]["core_distance"]
                    )
                elif c0_has:
                    core_distance = G.nodes[c0]["core_distance"]
                else:  # c1_has
                    core_distance = G.nodes[c1]["core_distance"]

                G.nodes[node]["core_distance"] = core_distance

       
        # Set the numbers of the nodes in the graph to 0 to num_samples-1 :
        G_nodes_reordering = {old_label: new_label for new_label, old_label in enumerate(G.nodes())}
        nx.relabel_nodes(G, G_nodes_reordering, copy=False)
        
        Graphs.append(G)

        # Process the graph to save it more easily:
        graph_nodes = list(G.nodes)
        graph_edges = list(G.edges)
        graph_edge_index = torch.tensor(np.array(graph_edges).T)

        node_features = []
        for node in graph_nodes:
            core = G.nodes[node].get("core_distance", 0.0)
            allele = G.nodes[node].get("allele_distance", 0.0)
            allele_only_new = G.nodes[node].get("allele_distance_only_new", 0.0)
            node_time = G.nodes[node].get("time", 0.0)
            node_features.append([core, allele, allele_only_new, node_time])
        node_features = torch.tensor(node_features, dtype=torch.float32)

        graph_properties.append([graph_nodes, graph_edge_index, node_features])

        nodes_in_simplified_tree = list(parents) + [clonal_root_node]
        for node, leaf in nodes_hgt_events[site.id]:
            while node not in nodes_in_simplified_tree:
                node = tree.parent(node)
            parental_nodes_hgt_events[site.id].append(node)
        for node in gene_nodes_loss_events[site.id]:
            stack = [node]
            while stack:
                node = stack.pop()
                if node in nodes_in_simplified_tree:
                    children_gene_nodes_loss_events[site.id].append(node)
                    break
                else:
                    if node >= num_samples:
                        child_list = tree.children(node)
                        stack.extend(child_list)
                    #if node in hgt_parent_nodes:
                    #    stack.append(node-1)

        # Move nodes with HGT events to a higher node, if there are not enough genes present under it.
        for hgt_node in parental_nodes_hgt_events[site.id]:
            node = hgt_node
            c0, c1 = children[node]
            while not (subtree_has_gene[c0] and subtree_has_gene[c1]) and node < clonal_root_node:
                node = parents[node]
                c0, c1 = children[node]
            if node < clonal_root_node or hgt_node == clonal_root_node:
                parental_nodes_hgt_events_corrected[site.id].append(node)
        
        parental_nodes_hgt_events_corrected[site.id] = [G_nodes_reordering[node] for node in parental_nodes_hgt_events_corrected[site.id]]
        parental_nodes_hgt_events[site.id] = [G_nodes_reordering[node] for node in parental_nodes_hgt_events[site.id]]
        children_gene_nodes_loss_events[site.id] = [G_nodes_reordering[node] for node in children_gene_nodes_loss_events[site.id]]
   
### Print the computation time.

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Success: hgt_rate = {hgt_rate}, Total computation time = {elapsed_time:.6f} seconds.")
# Out:
# Clonal node: 240
# Present_mutation at node:  209
# Number of present genes:  23
# Success: hgt_rate = 1, Total computation time = 0.507256 seconds.

# %%
for node, data in G.nodes(data=True):
    rounded_data = {
        key: round(value, 4) if isinstance(value, (int, float)) else value
        for key, value in data.items()
    }
    print(node, rounded_data)
# Out:
# 0 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 1 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 2 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 3 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 4 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 5 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 6 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 7 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 8 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 9 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 10 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 11 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 12 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 13 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 14 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 15 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 16 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 17 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 18 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 19 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 20 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 21 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 22 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 23 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 24 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 25 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 26 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 27 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 28 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 29 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 30 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 31 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 32 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 33 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 34 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 35 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 36 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 37 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 38 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 39 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 40 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 41 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 42 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 43 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 44 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 45 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 46 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 47 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 48 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 49 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 50 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 51 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 52 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 53 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 54 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 55 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 56 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 57 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 58 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 59 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 60 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 61 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 62 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 63 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 64 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 65 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 66 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 67 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 68 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 69 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 70 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 71 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 72 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 73 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 74 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 75 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 76 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 77 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 78 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 79 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 80 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 81 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 82 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 83 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 84 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 85 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 86 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 87 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 88 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 89 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 90 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 91 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 92 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 93 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 94 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 95 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 96 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 97 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 98 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 99 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 100 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0001, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 101 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0002, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 102 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0002, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 103 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0002, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 104 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0003, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 105 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0004, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 106 {'core_distance': 0.0009, 'allele_distance': 0.0, 'time': 0.0005, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0.0}
# 107 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0006, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 110 {'core_distance': 0.0016, 'allele_distance': 0.002, 'time': 0.0008, 'allele_distance_only_new': 0.002, 'true_allele_distance': 0.001}
# 109 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0008, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 108 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0007, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 113 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0025, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 112 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0022, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 111 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0014, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 116 {'core_distance': 0.0064, 'allele_distance': 0.003, 'time': 0.0032, 'allele_distance_only_new': 0.003, 'true_allele_distance': 0.003}
# 115 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0029, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 114 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0025, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 119 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0038, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 118 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0034, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 117 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0033, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 122 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0048, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 121 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0044, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 120 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0038, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 126 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0064, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 125 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.006, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 124 {'core_distance': 0.0117, 'allele_distance': 0.003, 'time': 0.0056, 'allele_distance_only_new': 0.003, 'true_allele_distance': 0.006}
# 123 {'core_distance': 0.0144, 'allele_distance': 0.006, 'time': 0.0056, 'allele_distance_only_new': 0.003, 'true_allele_distance': 0.007}
# 132 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0079, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 131 {'core_distance': 0.0224, 'allele_distance': 0.011, 'time': 0.0077, 'allele_distance_only_new': 0.003, 'true_allele_distance': 0.0109}
# 130 {'core_distance': 0.0232, 'allele_distance': 0.011, 'time': 0.0072, 'allele_distance_only_new': 0.005, 'true_allele_distance': 0.0109}
# 129 {'core_distance': 0.014, 'allele_distance': 0.008, 'time': 0.007, 'allele_distance_only_new': 0.008, 'true_allele_distance': 0.007}
# 128 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0067, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 127 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0065, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 138 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0097, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 137 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0095, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 136 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0094, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 135 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0087, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 134 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0085, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 133 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0082, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 144 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0127, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 143 {'core_distance': 0.0394, 'allele_distance': 0.02, 'time': 0.0123, 'allele_distance_only_new': 0.009, 'true_allele_distance': 0.0188}
# 142 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0123, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 141 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0109, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 140 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0104, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 139 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0098, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 150 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0175, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 149 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0173, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 148 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0173, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 147 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0155, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 146 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.013, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 145 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0129, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 156 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0197, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 155 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0194, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 154 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0194, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 153 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0193, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 152 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0187, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 151 {'core_distance': 0.0354, 'allele_distance': 0.015, 'time': 0.0177, 'allele_distance_only_new': 0.015, 'true_allele_distance': 0.0169}
# 162 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.024, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 161 {'core_distance': 0.0484, 'allele_distance': 0.034, 'time': 0.0238, 'allele_distance_only_new': 0.032, 'true_allele_distance': 0.0237}
# 160 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.023, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 159 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0228, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 158 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0201, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 157 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0199, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 173 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0385, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 172 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0383, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 171 {'core_distance': 0.0943, 'allele_distance': 0.041, 'time': 0.0383, 'allele_distance_only_new': 0.026, 'true_allele_distance': 0.045}
# 170 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0334, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 169 {'core_distance': 0.1085, 'allele_distance': 0.062, 'time': 0.0327, 'allele_distance_only_new': 0.031, 'true_allele_distance': 0.0516}
# 168 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0321, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 167 {'core_distance': 0.0633, 'allele_distance': 0.021, 'time': 0.0317, 'allele_distance_only_new': 0.021, 'true_allele_distance': 0.0305}
# 166 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0306, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 165 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0304, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 164 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0294, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 163 {'core_distance': 0.055, 'allele_distance': 0.027, 'time': 0.0275, 'allele_distance_only_new': 0.027, 'true_allele_distance': 0.0267}
# 185 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0823, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 184 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.08, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 183 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0597, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 182 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0588, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 181 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0538, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 180 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0524, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 179 {'core_distance': 0.2117, 'allele_distance': 0.095, 'time': 0.0512, 'allele_distance_only_new': 0.014, 'true_allele_distance': 0.0988}
# 178 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0506, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 177 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0487, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 176 {'core_distance': 0.2158, 'allele_distance': 0.105, 'time': 0.0475, 'allele_distance_only_new': 0.011, 'true_allele_distance': 0.1006}
# 175 {'core_distance': 0.1214, 'allele_distance': 0.06, 'time': 0.0439, 'allele_distance_only_new': 0.03, 'true_allele_distance': 0.0573}
# 174 {'core_distance': 0.1363, 'allele_distance': 0.06, 'time': 0.0401, 'allele_distance_only_new': 0.019, 'true_allele_distance': 0.0648}
# 198 {'core_distance': 1.075, 'allele_distance': 0.392, 'time': 1.4866, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0.4092}
# 197 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.5509, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 196 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.4181, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 195 {'core_distance': 1.075, 'allele_distance': 0.392, 'time': 0.4064, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0.4092}
# 194 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.2808, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 193 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.2753, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 192 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.2283, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 191 {'core_distance': 1.075, 'allele_distance': 0.392, 'time': 0.2065, 'allele_distance_only_new': 0.049, 'true_allele_distance': 0.4092}
# 190 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.1937, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 189 {'core_distance': 0.6676, 'allele_distance': 0.273, 'time': 0.1659, 'allele_distance_only_new': 0.081, 'true_allele_distance': 0.279}
# 188 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.1193, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
# 187 {'core_distance': 0.4275, 'allele_distance': 0.192, 'time': 0.0918, 'allele_distance_only_new': 0.034, 'true_allele_distance': 0.1887}
# 186 {'core_distance': 0, 'allele_distance': 0.0, 'time': 0.0886, 'allele_distance_only_new': 0.0, 'true_allele_distance': 0}
